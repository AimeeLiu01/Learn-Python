# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

broken_df = pd.read_csv('/Users/liuchang/Desktop/car.csv')
broken_df[:3]
# Out:
#    vhigh vhigh.1  2 2.1  small   low  unacc
# 0  vhigh   vhigh  2   2  small   med  unacc
# 1  vhigh   vhigh  2   2  small  high  unacc
# 2  vhigh   vhigh  2   2    med   low  unacc

# %%
broken_df['low']
# Out:
# 0        med
# 1       high
# 2        low
# 3        med
# 4       high
# 5        low
# 6        med
# 7       high
# 8        low
# 9        med
# 10      high
# 11       low
# 12       med
# 13      high
# 14       low
# 15       med
# 16      high
# 17       low
# 18       med
# 19      high
# 20       low
# 21       med
# 22      high
# 23       low
# 24       med
# 25      high
# 26       low
# 27       med
# 28      high
# 29       low
#         ...
# 1697     low
# 1698     med
# 1699    high
# 1700     low
# 1701     med
# 1702    high
# 1703     low
# 1704     med
# 1705    high
# 1706     low
# 1707     med
# 1708    high
# 1709     low
# 1710     med
# 1711    high
# 1712     low
# 1713     med
# 1714    high
# 1715     low
# 1716     med
# 1717    high
# 1718     low
# 1719     med
# 1720    high
# 1721     low
# 1722     med
# 1723    high
# 1724     low
# 1725     med
# 1726    high
# Name: low, Length: 1727, dtype: object

# %%
broken_df = pd.read_csv('/Users/liuchang/Desktop/comptagevelo2017.csv')
broken_df[:3]
# Out:
#          Date Unnamed: 1  Berri1  Boyer  Boyer 2  Brébeuf  Christophe-Colomb  \
# 0  01/01/2017      00:00      38     35      NaN       20                NaN
# 1  02/01/2017      00:00     109     40      0.0       43                NaN
# 2  03/01/2017      00:00     141     24     24.0        9                NaN
#
#    CSC (Côte Sainte-Catherine)  Eco-Totem - Métro Laurier  Maisonneuve_2  \
# 0                           60                         58             38
# 1                           61                         66            152
# 2                           14                        131            216
#
#        ...       Notre-Dame  Parc  PierDup  Pont Jacques-Cartier  \
# 0      ...               10    13        9                   0.0
# 1      ...                9    52       14                   0.0
# 2      ...               32    71       17                   0.0
#
#    Rachel / Hôtel de Ville  Rachel / Papineau  René-Lévesque  Saint-Antoine  \
# ...

# %%
broken_df['Date']
# Out:
# 0      01/01/2017
# 1      02/01/2017
# 2      03/01/2017
# 3      04/01/2017
# 4      05/01/2017
# 5      06/01/2017
# 6      07/01/2017
# 7      08/01/2017
# 8      09/01/2017
# 9      10/01/2017
# 10     11/01/2017
# 11     12/01/2017
# 12     13/01/2017
# 13     14/01/2017
# 14     15/01/2017
# 15     16/01/2017
# 16     17/01/2017
# 17     18/01/2017
# 18     19/01/2017
# 19     20/01/2017
# 20     21/01/2017
# 21     22/01/2017
# 22     23/01/2017
# 23     24/01/2017
# 24     25/01/2017
# 25     26/01/2017
# 26     27/01/2017
# 27     28/01/2017
# 28     29/01/2017
# 29     30/01/2017
#           ...
# 335    02/12/2017
# 336    03/12/2017
# 337    04/12/2017
# 338    05/12/2017
# 339    06/12/2017
# 340    07/12/2017
# 341    08/12/2017
# 342    09/12/2017
# 343    10/12/2017
# 344    11/12/2017
# 345    12/12/2017
# 346    13/12/2017
# 347    14/12/2017
# 348    15/12/2017
# 349    16/12/2017
# 350    17/12/2017
# 351    18/12/2017
# 352    19/12/2017
# 353    20/12/2017
# ...

# %%
broken_df['Berri1']
# Out:
# 0        38
# 1       109
# 2       141
# 3       233
# 4       265
# 5       306
# 6        96
# 7       113
# 8       362
# 9       451
# 10      458
# 11      440
# 12      398
# 13      125
# 14      120
# 15      507
# 16      576
# 17      459
# 18      495
# 19      518
# 20      265
# 21      194
# 22      557
# 23      185
# 24      434
# 25      518
# 26      441
# 27      173
# 28      173
# 29      421
#        ...
# 335     601
# 336     455
# 337    1373
# 338     873
# 339    1385
# 340    1266
# 341    1005
# 342     544
# 343     252
# 344     599
# 345     416
# 346     449
# 347     406
# 348     373
# 349     191
# 350     161
# 351     414
# 352     346
# 353     436
# 354     411
# 355     266
# 356      86
# 357      75
# 358      15
# 359      65
# 360     116
# 361     137
# 362     124
# 363      80
# 364      59
# Name: Berri1, Length: 365, dtype: int64

# %%
broken_df['Berri1'].plot()

# %%
broken_df.plot(figsize=(15,10))
