# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0,2.0, 0.01) ## 自变量t
s = np.sin(2*np.pi*t) ## 计算y
plt.plot(t, s)

# %%
plt.xlabel('t')
plt.ylabel('y')
# Out:
# Text(0,0.5,'y')

# %%
plt.title(r'image')
# Out:
# Text(0.5,1,'image')

# %%
plt.grid(True) # 🌹网格

# %%
plt.show()

# %%
## 直方图：plt.hist()
## 下面画一个均值为100， 方差sigma=15的正太分布的函数图像为例
import matplotlib.mlab as mlab
mu = 100
sigma = 15
x = mu + sigma*np.random.randn(1000) ## 生成矩形条的高度
num_bins = 10 # 矩形条的个数
n, bins, patches = plt.hist(x,num_bins)

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('histogram')
plt.show()

# %%
import matplotlib.mlab as mlab
mu = 100
sigma = 20
x = mu + sigma*np.random.randn(10000)
num_bins = 50 ## 矩形条的个数
# normed=1表示画的是概率密度，和为1；color：矩形条颜色；alpha：色深参数
n, bins, patches = plt.hist(x, num_bins, normed=1, color='green', alpha=0.6)
y = mlab.normpdf(bins, mu, sigma)
plt.plot(bins, y, 'r--')
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: scipy.stats.norm.pdf

# %%
plt.xlabel('x')
plt.ylabel('y')
plt.title('histogram')
plt.show()

# %%
## 3d离散点 ax.scatter()
from mpl_toolkits.mplot3d import Axes3D

# %%
x_list = [[1,2,3]]
fig = plt.figure()

# %%
ax = fig.gca(projection='3d') ## 返回坐标轴
for x in x_list:
    ax.scatter(x[0], x[1], x[2], c='r')
plt.show()

# %%
## 3d空间曲面ax.plot_surface()
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure()
ax = fig.gca(projection='3d')
X = np.arange(-5.5, 0.1) # X坐标 
Y = np.arange(-5.5, 0.1) # Y坐标
X,Y = np.meshgrid(X,Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R) ## 计算出Z坐标
surf = ax.plot_surface(X,Y,Z,rstride=1,cstride=1,cmap=cm.coolwarm,linewidth=0,antialiased=False)
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10)) #设置Z轴标度
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()

# %%
labels = 'Fogs', 'Hogs', 'Dogs', 'Logs'
size = [15, 30, 45, 10]
colors = ['yellow', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.1, 0, 0)
plt.pie(size, explode=explode, labels=labels, colors=colors, shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x115f01550>,
# ...
#  [Text(-0.49939,0.980107,'Fogs'),
#   Text(-1.14127,-0.37082,'Hogs'),
#   Text(0.980107,-0.499389,'Dogs'),
#   Text(0.339919,1.04616,'Logs')])

# %%
plt.show()

# %%
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
size = [15, 30, 45, 10]
colors = ['yellow', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1, 0)
## autopct参数表示显示百分数，且决定了百分比的格式
plt.pie(size, explode=explode, labels=labels, colors=colors,
       shadow=True, autopct='%1.1f%%', startangle=90)
plt.show()
